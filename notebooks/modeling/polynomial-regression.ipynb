# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.linalg import lstsq
TABLE_FOLDER = '../../src/data'
RAW_FILE = 'transformed_dataset_v1.csv'

df = pd.read_csv(f'{TABLE_FOLDER}/{RAW_FILE}', parse_dates=['date'])
df.drop('Unnamed: 0', axis=1, inplace=True)

df.dtypes
# Out:
# date                    datetime64[ns]
# home_team                       object
# away_team                       object
# last_h_goals                   float64
# last_a_goals                   float64
# last_wh_goals                  float64
# last_wa_goals                  float64
# odd_1                          float64
# odd_N                          float64
# odd_2                          float64
# home_trend_slope               float64
# home_trend_intercept           float64
# away_trend_slope               float64
# away_trend_intercept           float64
# target                         float64
# dtype: object

# %%
np.unique(df.date)[-4:]
# Out:
# array(['2022-05-16T00:00:00.000000000', '2022-05-17T00:00:00.000000000',
#        '2022-05-19T00:00:00.000000000', '2022-05-22T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
last_date = df.date.max()
df.query('date == @last_date')
# Out:
#            date        home_team       away_team  last_h_goals  last_a_goals  \
# 938  2022-05-22        Liverpool          Wolves           3.0           4.0
# 1555 2022-05-22          Chelsea         Watford           5.0           3.0
# 2205 2022-05-22        Leicester     Southampton           7.0           4.0
# 2648 2022-05-22  Manchester City     Aston Villa           4.0           8.0
# 4273 2022-05-22   Crystal Palace  Manchester Utd           5.0           5.0
# 4873 2022-05-22         Brighton        West Ham           6.0           8.0
# 6083 2022-05-22        Brentford           Leeds           6.0           2.0
# 6185 2022-05-22          Norwich       Tottenham          13.0           8.0
#
#       last_wh_goals  last_wa_goals  odd_1  odd_N  odd_2  home_trend_slope  \
# 938             8.0           12.0   1.13   9.19  19.26               4.4
# 1555            7.0           13.0   1.19   7.41  15.39               2.5
# 2205           11.0           11.0   1.70   4.26   4.54               1.7
# 2648           21.0            5.0   1.17   8.21  15.57               5.0
# 4273            6.0           12.0   2.81   3.47   2.50               4.0
# 4873           10.0            6.0   2.66   3.46   2.65               3.0
# 6083            8.0           10.0   2.32   3.79   2.88               2.3
# 6185            1.0            2.0   9.94   5.55   1.31              -1.0
#
#       home_trend_intercept  away_trend_slope  away_trend_intercept  target
# 938                    3.4               0.2          4.000000e-01     0.0
# 1555                   0.5              -0.4         -8.000000e-01     0.0
# 2205                   5.5               0.6         -3.400000e+00     0.0
# 2648                  -0.2               2.3         -2.900000e+00     0.0
# 4273                  -4.0               0.9          3.000000e-01     0.0
# 4873                   2.0               1.0          2.600000e+00     0.0
# 6083                   4.3              -0.2          1.986027e-16     2.0
# 6185                   5.4               3.5         -7.000000e-01     2.0

# %%
dataset = df.copy()


last_date = '2022-05-01' #dataset.date.max()
unseen_index=dataset.query('date >= @last_date').index.tolist()
training_index=dataset.query('date <= @last_date').index.tolist()

data = dataset.loc[training_index,:]
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (6513, 15)
# Unseen Data For Predictions: (30, 15)

# %%
for idx, r in data.iterrows():
    if r.target == 0:
        data.loc[idx,'odds']=r.odd_1
    elif r.target == 1:
        data.loc[idx,'odds']=r.odd_N
    else:
        data.loc[idx,'odds']=r.odd_2


#drop all rows with odds >5.9

del_row = data.query('odds>5.9').index.tolist()
data.drop(del_row, inplace=True)
data.shape
# Out:
# (6296, 16)

# %%
r_cols = ['odd_1','odd_N','odd_2','target','date','home_team','away_team']
df = data.drop(r_cols,axis=1).copy()

# %%
# EDA
df.describe()
# Out:
#        last_h_goals  last_a_goals  last_wh_goals  last_wa_goals  \
# count    6296.00000   6296.000000    6296.000000    6296.000000
# mean        6.77986      6.768742       6.534307       6.586563
# std         3.01942      3.194149       3.121694       2.978046
# min         0.00000      0.000000       0.000000       0.000000
# 25%         5.00000      4.000000       4.000000       4.000000
# 50%         7.00000      6.000000       6.000000       6.000000
# 75%         9.00000      9.000000       8.000000       8.000000
# max        20.00000     24.000000      29.000000      20.000000
#
#        home_trend_slope  home_trend_intercept  away_trend_slope  \
# count       6296.000000           6296.000000       6296.000000
# mean           2.015867              0.469076          2.043949
# std            1.495391              3.392473          1.483806
# min           -1.600000             -9.200000         -1.600000
# 25%            0.900000             -2.100000          1.000000
# 50%            1.900000              0.300000          2.000000
# 75%            3.100000              2.900000          3.100000
# max            7.000000             10.000000          6.200000
#
#        away_trend_intercept         odds
# count           6296.000000  6296.000000
# mean              -0.474603     2.562424
# std                3.038341     1.025843
# min              -10.800000     1.040000
# 25%               -2.600000     1.680000
# 50%               -0.500000     2.380000
# 75%                1.700000     3.290000
# max                9.900000     5.890000

# %%
X = df.drop('odds', axis=1).values
y = df.odds.values

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=1, svd_solver='arpack')
X_pca=pca.fit_transform(X)

# %%
import numpy as np

coefs = np.polyfit(X_pca.flatten(), y, deg=1)
#a, b, c, d = coefs
a, b = coefs
print('Coefficients:', coefs) # [ 0.77788056 -0.3904125 ]
# Out:
# Coefficients: [-0.01075727  2.56242376]

# %%
data_unseen
# Out:
#          date        home_team        away_team  last_h_goals  last_a_goals  \
# 0  2022-05-07         Brighton   Manchester Utd           6.0           8.0
# 1  2022-05-15          Watford        Leicester          10.0           6.0
# 2  2022-05-02   Manchester Utd        Brentford          11.0           9.0
# 3  2022-05-22        Liverpool           Wolves           3.0           4.0
# 4  2022-05-08          Arsenal            Leeds           7.0           7.0
# 5  2022-05-15      Aston Villa   Crystal Palace           7.0           4.0
# 6  2022-05-22          Chelsea          Watford           5.0           3.0
# 7  2022-05-22        Leicester      Southampton           7.0           4.0
# 8  2022-05-07          Chelsea           Wolves           6.0           4.0
# 9  2022-05-22  Manchester City      Aston Villa           4.0           8.0
# 10 2022-05-07        Liverpool        Tottenham           2.0          12.0
# 11 2022-05-11        Leicester          Norwich           8.0           4.0
# 12 2022-05-15         West Ham  Manchester City           6.0          22.0
# 13 2022-05-12        Tottenham          Arsenal           3.0          11.0
# 14 2022-05-11            Leeds          Chelsea           7.0           6.0
# 15 2022-05-22   Crystal Palace   Manchester Utd           5.0           5.0
# 16 2022-05-15        Tottenham          Burnley           3.0           7.0
# 17 2022-05-19          Everton   Crystal Palace           6.0           4.0
# 18 2022-05-07          Burnley      Aston Villa           4.0           3.0
# 19 2022-05-22         Brighton         West Ham           6.0           8.0
# 20 2022-05-08  Manchester City        Newcastle           3.0           7.0
# 21 2022-05-15          Everton        Brentford           4.0           7.0
# 22 2022-05-19      Aston Villa          Burnley           4.0           6.0
# 23 2022-05-17      Southampton        Liverpool           9.0          10.0
# 24 2022-05-11           Wolves  Manchester City           8.0          19.0
# 25 2022-05-10      Aston Villa        Liverpool           7.0          10.0
# 26 2022-05-22        Brentford            Leeds           6.0           2.0
# 27 2022-05-22          Norwich        Tottenham          13.0           8.0
# 28 2022-05-16        Newcastle          Arsenal           7.0          11.0
# 29 2022-05-08        Leicester          Everton           7.0           5.0
#
#     last_wh_goals  last_wa_goals  odd_1  odd_N  odd_2  home_trend_slope  \
# 0             8.0           10.0   3.03   3.34   2.44               3.7
# 1             3.0            6.0   5.12   3.95   1.69              -1.0
# 2             5.0            4.0   1.76   3.95   4.55               0.9
# 3             8.0           12.0   1.13   9.19  19.26               4.4
# 4            10.0            7.0   1.52   4.51   6.18               2.3
# 5             6.0            4.0   1.84   3.56   4.54               3.1
# 6             7.0           13.0   1.19   7.41  15.39               2.5
# 7            11.0           11.0   1.70   4.26   4.54               1.7
# 8            10.0            9.0   1.37   4.89   9.21               2.5
# 9            21.0            5.0   1.17   8.21  15.57               5.0
# 10           11.0            3.0   1.43   5.08   7.00               3.3
# 11            4.0           12.0   1.33   5.60   9.12               1.5
# 12            6.0            2.0   7.94   5.18   1.38              -0.1
# 13            8.0            6.0   2.28   3.45   3.21               2.6
# 14            5.0            8.0   4.87   4.11   1.68               3.1
# 15            6.0           12.0   2.81   3.47   2.50               4.0
# 16            7.0            5.0   1.31   5.54  10.28               2.5
# 17            5.0            3.0   1.86   3.50   4.58               3.8
# 18            6.0            7.0   3.09   3.16   2.48               2.7
# 19           10.0            6.0   2.66   3.46   2.65               3.0
# 20           16.0            2.0   1.18   7.85  16.22               3.2
# 21            4.0            4.0   1.90   3.60   4.22               2.5
# 22            7.0            5.0   2.03   3.46   3.85               3.4
# 23            4.0            2.0   6.64   4.90   1.46               1.4
# 24            4.0            3.0  11.97   6.14   1.26               0.2
# 25            6.0            3.0   6.39   4.52   1.51               1.2
# 26            8.0           10.0   2.32   3.79   2.88               2.3
# 27            1.0            2.0   9.94   5.55   1.31              -1.0
# 28            6.0            8.0   4.28   3.78   1.84               3.2
# 29            5.0            6.0   2.65   3.25   2.80               2.0
#
#     home_trend_intercept  away_trend_slope  away_trend_intercept  target
# 0                    0.9      8.000000e-01          2.000000e+00     0.0
# 1                    2.4      7.000000e-01          5.000000e-01     2.0
# 2                   -0.5      4.400000e+00         -2.000000e+00     0.0
# 3                    3.4      2.000000e-01          4.000000e-01     0.0
# 4                    6.3      4.600000e+00         -6.600000e+00     0.0
# 5                   -2.7      1.700000e+00          4.100000e+00     1.0
# 6                    0.5     -4.000000e-01         -8.000000e-01     0.0
# 7                    5.5      6.000000e-01         -3.400000e+00     0.0
# 8                   -1.9      5.000000e-01         -2.700000e+00     1.0
# 9                   -0.2      2.300000e+00         -2.900000e+00     0.0
# 10                   3.5      2.900000e+00         -3.000000e-01     1.0
# 11                  -4.3     -5.988098e-17         -2.600000e+00     0.0
# 12                   6.1      4.200000e+00          2.800000e+00     1.0
# 13                   1.6      4.400000e+00          1.588822e-15     0.0
# 14                  -5.5      1.700000e+00         -9.000000e-01     2.0
# 15                  -4.0      9.000000e-01          3.000000e-01     0.0
# 16                   1.7      4.000000e+00         -4.600000e+00     0.0
# 17                  -4.8      3.000000e+00          2.000000e+00     0.0
# 18                   4.7     -2.000000e-01          5.200000e+00     2.0
# 19                   2.0      1.000000e+00          2.600000e+00     0.0
# 20                   3.4      3.800000e+00         -4.200000e+00     0.0
# 21                   4.1      3.000000e+00         -2.000000e+00     2.0
# 22                  -4.6      3.200000e+00         -5.200000e+00     1.0
# 23                  -2.8      3.800000e+00          2.400000e+00     2.0
# 24                   2.4      3.400000e+00          1.600000e+00     2.0
# 25                   7.4      4.000000e+00         -1.600000e+00     2.0
# 26                   4.3     -2.000000e-01          1.986027e-16     2.0
# 27                   5.4      3.500000e+00         -7.000000e-01     2.0
# 28                  -5.2      5.000000e+00         -5.800000e+00     0.0
# 29                  -2.2      1.200000e+00          1.200000e+00     2.0

# %%
X_u = data_unseen.drop(['odd_1','odd_N','odd_2','target','date','home_team','away_team'],axis=1).copy()

# %%
X_u_pca = pca.transform(X_u)
# Out:
# /opt/anaconda3/envs/pyomo/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but PCA was fitted without feature names
#   warnings.warn(

# %%
import numpy as np

scores = []
for x in range(0,data_unseen.shape[0]):
    key=x
    game_day = data_unseen.loc[key,'date']
    home_team = data_unseen.loc[key,'home_team']
    away_team = data_unseen.loc[key,'away_team']
    x_values2=X_u_pca[key] 
    #odd=a*(x_values2**3) + b*(x_values2**2) + c*x_values2 + d
    odd = (a*x_values2) + b
    r = data_unseen.loc[key,['odd_1','odd_N','odd_2','target']].tolist()
    bett = r[:3]
    winner = int(r[3])
    ret = np.abs(bett - odd)

    index_min = np.argmin(ret)
    if winner == index_min: 
        result=True 
    else: 
        result=False
    error = bett[index_min] - odd[0]

    if bett[winner]/odd[0] > 0.95 and bett[winner]/odd[0] < 1.05:
        investment = 3
    else:
        investment = 1
    returns = bett[int(winner)] * investment   
    scores.append([game_day, home_team, away_team, np.round(odd[0],2), r[:3], int(winner), index_min, 
        bett[winner]/odd[0], error, result, returns, investment])

scores = pd.DataFrame(scores)
scores.columns = ['date','home_team','away_team','predict','odds','winner','you_play','diff','error','correct','possible-return','investment']

scores
# Out:
#          date        home_team        away_team  predict                 odds  \
# 0  2022-05-07         Brighton   Manchester Utd     2.57   [3.03, 3.34, 2.44]
# 1  2022-05-15          Watford        Leicester     2.59   [5.12, 3.95, 1.69]
# 2  2022-05-02   Manchester Utd        Brentford     2.54   [1.76, 3.95, 4.55]
# 3  2022-05-22        Liverpool           Wolves     2.60  [1.13, 9.19, 19.26]
# 4  2022-05-08          Arsenal            Leeds     2.53   [1.52, 4.51, 6.18]
# 5  2022-05-15      Aston Villa   Crystal Palace     2.58   [1.84, 3.56, 4.54]
# 6  2022-05-22          Chelsea          Watford     2.63  [1.19, 7.41, 15.39]
# 7  2022-05-22        Leicester      Southampton     2.59    [1.7, 4.26, 4.54]
# 8  2022-05-07          Chelsea           Wolves     2.59   [1.37, 4.89, 9.21]
# 9  2022-05-22  Manchester City      Aston Villa     2.49  [1.17, 8.21, 15.57]
# 10 2022-05-07        Liverpool        Tottenham     2.47    [1.43, 5.08, 7.0]
# 11 2022-05-11        Leicester          Norwich     2.63    [1.33, 5.6, 9.12]
# 12 2022-05-15         West Ham  Manchester City     2.43   [7.94, 5.18, 1.38]
# 13 2022-05-12        Tottenham          Arsenal     2.51   [2.28, 3.45, 3.21]
# 14 2022-05-11            Leeds          Chelsea     2.59   [4.87, 4.11, 1.68]
# 15 2022-05-22   Crystal Palace   Manchester Utd     2.61    [2.81, 3.47, 2.5]
# 16 2022-05-15        Tottenham          Burnley     2.52  [1.31, 5.54, 10.28]
# 17 2022-05-19          Everton   Crystal Palace     2.57    [1.86, 3.5, 4.58]
# 18 2022-05-07          Burnley      Aston Villa     2.60   [3.09, 3.16, 2.48]
# 19 2022-05-22         Brighton         West Ham     2.55   [2.66, 3.46, 2.65]
# 20 2022-05-08  Manchester City        Newcastle     2.48  [1.18, 7.85, 16.22]
# 21 2022-05-15          Everton        Brentford     2.53     [1.9, 3.6, 4.22]
# 22 2022-05-19      Aston Villa          Burnley     2.54   [2.03, 3.46, 3.85]
# 23 2022-05-17      Southampton        Liverpool     2.53    [6.64, 4.9, 1.46]
# 24 2022-05-11           Wolves  Manchester City     2.47  [11.97, 6.14, 1.26]
# 25 2022-05-10      Aston Villa        Liverpool     2.51   [6.39, 4.52, 1.51]
# 26 2022-05-22        Brentford            Leeds     2.61   [2.32, 3.79, 2.88]
# 27 2022-05-22          Norwich        Tottenham     2.55   [9.94, 5.55, 1.31]
# 28 2022-05-16        Newcastle          Arsenal     2.53   [4.28, 3.78, 1.84]
# 29 2022-05-08        Leicester          Everton     2.59    [2.65, 3.25, 2.8]
#
#     winner  you_play      diff     error  correct  possible-return  investment
# 0        0         2  1.177120 -0.134079    False             3.03           1
# 1        2         2  0.652008 -0.901993     True             1.69           1
# 2        0         0  0.693056 -0.779476     True             1.76           1
# 3        0         0  0.434599 -1.470096     True             1.13           1
# 4        0         0  0.601678 -1.006270     True             1.52           1
# 5        1         0  1.379329 -0.740965    False             3.56           1
# 6        0         0  0.453106 -1.436319     True             1.19           1
# 7        0         0  0.656571 -0.889209     True             1.70           1
# 8        1         0  1.890934 -1.216024    False             4.89           1
# 9        0         0  0.470493 -1.316753     True             1.17           1
# 10       1         0  2.054886 -1.042157    False             5.08           1
# 11       0         0  0.505356 -1.301810     True             1.33           1
# 12       1         2  2.134671 -1.046604    False             5.18           1
# 13       0         0  0.909811 -0.226016     True             2.28           1
# 14       2         2  0.649664 -0.905951     True             1.68           1
# 15       0         2  1.076615 -0.110032    False             2.81           1
# 16       0         0  0.519296 -1.212646     True             1.31           1
# 17       0         0  0.724387 -0.707690     True             1.86           1
# 18       2         2  0.954384 -0.118535     True             7.44           3
# 19       0         2  1.044973  0.104480    False             7.98           3
# 20       0         0  0.476099 -1.298479     True             1.18           1
# 21       2         0  1.665026 -0.634496    False             4.22           1
# 22       1         0  1.362631 -0.509205    False             3.46           1
# 23       2         2  0.576846 -1.071005     True             1.46           1
# 24       2         2  0.510517 -1.208088     True             1.26           1
# 25       2         2  0.602452 -0.996423     True             1.51           1
# 26       2         2  1.102158  0.266944     True             2.88           1
# 27       2         2  0.512933 -1.243939     True             1.31           1
# 28       0         2  1.693797 -0.686867    False             4.28           1
# 29       2         0  1.083055  0.064720    False             2.80           1

# %%
returns_cash = np.round(scores.query('correct==True')['possible-return'].sum()-scores.investment.sum(),2)
total_returns = np.round(scores.query('correct==True')['possible-return'].sum(),2)
invest_cash = scores.investment.sum()
nb_games = scores.shape[0]

print(f'Betting on {nb_games} games a total of {invest_cash}$ will return {total_returns}$ for net: {returns_cash}$')
# Out:
# Betting on 30 games a total of 34$ will return 35.66$ for net: 1.66$
